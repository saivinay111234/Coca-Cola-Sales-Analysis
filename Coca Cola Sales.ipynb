# %% [markdown]
# # Business Objectives
#
# Temporal Analysis:
#
# 1. What are the seasonal sales trends of Coca-Cola products, and how can we adjust our promotions to align with peak sales periods?
#
# 2. Regional Performance: Which regions demonstrate the highest and lowest sales performance for Coca-Cola products, and what strategies can be
# implemented to improve sales in underperforming regions?
#
# 3. Product Line Analysis: Which individual product lines contribute the most to Coca-Cola’s revenue, and how can we optimize the performance of
# lower-performing product lines?
#
# 4. Correlation Analysis: What are the relationships between sales volume, revenue, and external factors such as marketing campaigns and
# economic indicators, and how can we establish key performance indicators (KPIs) based on these correlations?

# %% [markdown]
# # Analysis:
#
# 1. Sales Performance Analysis
# Total Sales by Retailer: Identify which retailers are generating the most revenue. This can help prioritize key accounts.
# Total Sales by Region/State/City: Analyze sales performance across different geographical areas to identify strong and weak markets.
# Top-Selling Beverage Brands: Determine which beverage brands are the most popular and contribute the most to total sales.
#
#
# 2. Operational Efficiency Analysis
# Days to Deliver Analysis: Evaluate the average delivery times to understand the efficiency of the supply chain. Identify if certain regions or
# delivery companies have longer delivery times.
#
#
# 3. Profitability Analysis
# Operating Profit by Retailer/Region/Brand: Assess which retailers, regions, and brands are the most profitable.
# Operating Margin Analysis: Analyze operating margins to understand which products or markets are the most efficient in generating profit.
#
# 4. Pricing Strategy Analysis
# Price per Unit Analysis: Examine how the price per unit varies across different regions, brands, and retailers. Identify if higher prices
# correlate with higher sales or profits.
#
#
# 5. Market Trends and Seasonality
# Sales Over Time: Analyze sales data over time (using the Invoice Date) to identify trends, seasonal patterns, and peak sales periods.
#
#
# 6. Customer Behavior and Preferences
# Retailer Purchase Patterns: Study the purchase patterns of different retailers to understand their preferences and buying behavior.
# Brand Loyalty: Determine if certain retailers consistently purchase specific beverage brands, indicating brand loyalty.
#
#
# 7. Delivery and Logistics Insights
# Correlation Between Days to Deliver and Sales: Investigate if longer delivery times impact the number of units sold or total sales.

# %% [markdown]
# # Here are the analyses we can draw from the provided charts:
#
# ### Total Sales by Retailer:
#
# Walmart has the highest total sales, indicating it is the top-performing retailer in terms of revenue.
# CVS follows as the second highest, showing it is also a significant contributor to sales.
# Costco and Target have lower total sales compared to Walmart and CVS, suggesting that these retailers may need focused promotional strategies to boost their sales.
#
# ### Operating Profit by Retailer:
# Target has the highest operating profit, which suggests it is very efficient in its operations and possibly has higher profit margins or lower costs.
# Costco and CVS also show strong operating profits, indicating they are profitable despite potentially lower sales volumes compared to Walmart.
# Walmart, although having the highest total sales, has the lowest operating profit among the four, indicating higher operational costs or lower profit margins.
#
# ### Operating Profit by Region:
# The Southeast region stands out with the highest operating profit, making it the most profitable region. Efforts should be made to maintain and further enhance profitability here.
# The West and South regions also show strong operating profits, indicating good performance.
# The Northeast region has moderate operating profits, suggesting potential for improvement.
# The Midwest region has the lowest operating profit, indicating it might need strategic interventions to improve profitability.
#
#
#
# From these analyses, the following strategic actions can be considered:
#
# For Walmart:
#
# Investigate why the high sales volume is not translating into higher profits and work on cost optimization strategies.
# For Target, CVS, and Costco:
#
# Maintain and enhance the current operational efficiencies to ensure sustained profitability.
# For Regional Strategy:
#
# Focus on boosting profitability in the Northeast and Midwest regions through targeted marketing, operational improvements, and cost management.
#
#
#
#
# ### Sales by Time Series
# 1. There appears to be some seasonality to the sales data, with sales peaking in July and December. This could be due to holiday shopping.
# 2. Sales are lowest during Q1 and Q3.
# 3. Overall, sales appear to be relatively flat from January 2022 to March 2022, then increase significantly from April 2022 to July 2022.
# 4. Sales appear to be increasing steadily over the quarters shown in the graph (from Q1 2022 to Q3 2022). There is a gradual increase
# in total sales from each quarter to the next.
#
#
# ### Purchase Frequency and Popular products
# 1. Customers tend to visit CVS, Target, and Costco less frequently, but when they do, they make larger purchases (higher average order value)
# and tend to buy popular brands like Coca-Cola and Dasani Water, and Diet Coke.
# 2. Customers visit Walmart more frequently, but make smaller purchases each time (lower average order value). Popular purchases at Walmart
# might include Coca-Cola, Diet Coke, and Sprite.
#
# Linear relationship
# it indicates that there is no significant linear relationship between "Days to Deliver" and "Total Sales" or "Units Sold."
# This means that changes in delivery times do not appear to have a direct linear impact on sales metrics
#
#
# ### Key Insights:
#
# High Positive Correlations:
# Total Sales and Units Sold (0.87): There's a strong positive correlation between total sales and units sold, indicating that higher unit sales
# lead to higher total sales.
# Total Sales and Operating Profit (0.92): Total sales have a strong positive correlation with operating profit, meaning higher sales generally
# result in higher operating profit.
# Units Sold and Operating Profit (0.83): More units sold tend to result in higher operating profit, reinforcing the importance of volume in
# profitability.
# Total Sales and Sales per Unit (0.64): This suggests that the sales per unit metric is a significant contributor to total sales.
#
# ### Moderate Positive Correlations:
# Total Sales and Price per Unit (0.48): Higher prices per unit are associated with higher total sales, though the relationship is not as strong
#     as with units sold.
# Operating Profit and Price per Unit (0.54): There's a moderate correlation between price per unit and operating profit, indicating that pricing
#     strategies can impact profitability.
# Delivery Efficiency and Total Sales (0.69): Efficient deliveries are moderately correlated with higher total sales, emphasizing the importance
#     of logistics.
#
# ### Low Positive Correlations:
# Days to Deliver and Delivery Efficiency (0.51): Longer delivery times slightly correlate with better delivery efficiency, which might indicate
#     efficient handling of complex deliveries.
# Invoice Date and Profit Margin (0.20): Recent sales data have a slight positive correlation with profit margin, which could indicate improving
# profitability over time.
#
# ### Low or Negative Correlations:
# Operating Margin and Total Sales (-0.04): Operating margin has a very low negative correlation with total sales, suggesting that increased
# sales do not necessarily lead to higher margins.
# Days to Deliver and Units Sold (-0.35): Longer delivery times have a moderate negative correlation with units sold, indicating that faster
#     deliveries might boost sales volume.
# Region and Profit Margin (-0.07): Different regions show little to no impact on profit margin, implying regional differences may not be
#     significant in determining profitability.
#
# ### Specific Relationships to Explore Further:
# Units Sold and Delivery Efficiency: The moderate positive correlation (0.69) suggests improving delivery efficiency can boost sales volume.
# Price per Unit and Profit per Unit: A strong positive correlation (0.76) indicates that higher pricing generally results in higher
#     profit per unit, highlighting the importance of pricing strategies.
# Operating Margin and Sales per Unit (-0.09): The slightly negative correlation suggests a potential trade-off between maintaining high
#     sales per unit and operating margin.
#
#
# ### Actionable Insights:
# Focus on Sales Volume: Since units sold strongly correlate with both total sales and operating profit, strategies to boost sales volume
# (e.g., promotions, discounts) could be beneficial.
# Improve Delivery Efficiency: Enhancing delivery efficiency could lead to higher sales and improved customer satisfaction.
# Optimize Pricing: Given the strong correlation between price per unit and profit per unit, review and optimize pricing strategies to
#     maximize profitability.
# Monitor and Adjust Inventory: Ensure inventory levels are aligned with sales trends to avoid stockouts and minimize holding costs.
#
#
#
# Relationship between Stock price of Coca Cola and Sales
# Total Sales and Adj Close: A correlation of 0.266480 suggests a weak positive correlation between total sales and Coca-Cola's stock price.
# Price per Unit and Adj Close: A correlation of 0.260235 suggests a weak positive correlation between the price per unit and Coca-Cola's stock price.
# Units Sold and Adj Close: A correlation of 0.162118 suggests a very weak positive correlation between units sold and Coca-Cola's stock price.
# Operating Profit and Adj Close: A correlation of 0.219084 suggests a weak positive correlation between operating profit and Coca-Cola's stock price.
# Operating Margin and Adj Close: A correlation of -0.005497 suggests almost no correlation between operating margin and Coca-Cola's stock price.

# %%
# %pip install seaborn
# Out:
# ...
#
# ...

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Coca Cola Sales Data.csv")
print(data)
# Out:
#      Retailer  Retailer ID Invoice Date     Region          State        City  \
# 0     Walmart      1185732    1/14/2022  Northeast       New York    New York
# 1     Walmart      1185732    1/14/2022  Northeast       New York    New York
# 2     Walmart      1185732    1/14/2022  Northeast       New York    New York
# 3     Walmart      1185732    1/14/2022  Northeast       New York    New York
# 4     Walmart      1185732    1/14/2022  Northeast       New York    New York
# ...       ...          ...          ...        ...            ...         ...
# 3739  Walmart      1185732   12/20/2022  Northeast  New Hampshire  Manchester
# 3740  Walmart      1185732   12/20/2022  Northeast  New Hampshire  Manchester
# 3741  Walmart      1185732   12/20/2022  Northeast  New Hampshire  Manchester
# 3742  Walmart      1185732   12/20/2022  Northeast  New Hampshire  Manchester
# 3743  Walmart      1185732   12/20/2022  Northeast  New Hampshire  Manchester
#
# ...

# %%
# Data Preprocessing
data.isnull().sum()
# Out:
# Retailer              0
# Retailer ID           0
# Invoice Date          0
# Region                0
# State                 0
# City                  0
# Beverage Brand        0
# Days to \nDeliver     0
# Delivery \nCompany    0
# Price per \nUnit      0
# Units Sold            0
# Total Sales           0
# Operating Profit      0
# Operating Margin      0
# dtype: int64

# %%
data = data.rename(columns={
    'Days to \nDeliver': 'Days to Deliver',
    'Delivery \nCompany': 'Delivery Company',
    'Price per \nUnit' : 'Price per Unit'
})

data.columns
# Out:
# Index(['Retailer', 'Retailer ID', 'Invoice Date', 'Region', 'State', 'City',
#        'Beverage Brand', 'Days to Deliver', 'Delivery Company',
#        'Price per Unit', 'Units Sold', 'Total Sales', 'Operating Profit',
#        'Operating Margin'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Retailer            object
# Retailer ID          int64
# Invoice Date        object
# Region              object
# State               object
# City                object
# Beverage Brand      object
# Days to Deliver      int64
# Delivery Company    object
# Price per Unit      object
# Units Sold          object
# Total Sales         object
# Operating Profit    object
# Operating Margin    object
# dtype: object

# %%
data.describe()

# Analysis Findings:
# The Average no of days to deliver the product is 37 days. while the lowest no of days is 15 days and Max time to deliver the product is 60 days.
# Out:
#         Retailer ID  Days to Deliver
# count  3.744000e+03      3744.000000
# mean   1.176706e+06        37.174145
# std    2.400406e+04        13.304029
# min    1.128299e+06        15.000000
# 25%    1.185732e+06        26.000000
# 50%    1.185732e+06        37.000000
# 75%    1.185732e+06        49.000000
# max    1.197831e+06        60.000000

# %%
df = data

# %%
# Remove non-numeric characters and convert to numeric
df['Price per Unit'] = df['Price per Unit'].str.replace('[\$,]', '', regex=True).astype(float)
df['Units Sold'] = df['Units Sold'].str.replace(',', '').astype(int)
df['Total Sales'] = df['Total Sales'].str.replace('[\$,]', '', regex=True).astype(float)
df['Operating Profit'] = df['Operating Profit'].str.replace('[\$,]', '', regex=True).astype(float)
df['Operating Margin'] = df['Operating Margin'].str.replace('%', '', regex=True).astype(float) / 100

# Display the updated DataFrame
df
# Out:
#      Retailer  Retailer ID Invoice Date     Region          State        City  \
# 0     Walmart      1185732    1/14/2022  Northeast       New York    New York
# 1     Walmart      1185732    1/14/2022  Northeast       New York    New York
# 2     Walmart      1185732    1/14/2022  Northeast       New York    New York
# 3     Walmart      1185732    1/14/2022  Northeast       New York    New York
# 4     Walmart      1185732    1/14/2022  Northeast       New York    New York
# ...       ...          ...          ...        ...            ...         ...
# 3739  Walmart      1185732   12/20/2022  Northeast  New Hampshire  Manchester
# 3740  Walmart      1185732   12/20/2022  Northeast  New Hampshire  Manchester
# 3741  Walmart      1185732   12/20/2022  Northeast  New Hampshire  Manchester
# 3742  Walmart      1185732   12/20/2022  Northeast  New Hampshire  Manchester
# 3743  Walmart      1185732   12/20/2022  Northeast  New Hampshire  Manchester
#
# ...

# %%
df.dtypes
# Out:
# Retailer             object
# Retailer ID           int64
# Invoice Date         object
# Region               object
# State                object
# City                 object
# Beverage Brand       object
# Days to Deliver       int64
# Delivery Company     object
# Price per Unit      float64
# Units Sold            int32
# Total Sales         float64
# Operating Profit    float64
# Operating Margin    float64
# dtype: object

# %%
cat_col = ['Retailer', 'Region', 'State', 'City', 'Beverage Brand',	'Delivery Company']
for i in cat_col:
    print(f'Unique values in the "{i}" column are : {df[i].unique()}')
    print(df[i].value_counts())
    print("\n")
# Out:
# Unique values in the "Retailer" column are : ['Walmart' 'Costco' 'CVS' 'Target']
# Retailer
# Walmart    2304
# CVS         720
# Costco      576
# Target      144
# Name: count, dtype: int64
#
#
# Unique values in the "Region" column are : ['Northeast' 'South' 'West' 'Midwest' 'Southeast']
# Region
# Northeast    936
# Midwest      936
# West         792
# South        576
# Southeast    504
# Name: count, dtype: int64
#
#
# Unique values in the "State" column are : ['New York' 'Texas' 'California' 'Illinois' 'Pennsylvania' 'Nevada'
#  'Colorado' 'Washington' 'Florida' 'Minnesota' 'Montana' 'Tennessee'
#  'Nebraska' 'Alabama' 'Maine' 'Wyoming' 'Virginia' 'Michigan' 'Missouri'
#  'Utah' 'Oregon' 'Louisiana' 'Idaho' 'Arizona' 'New Mexico' 'Georgia'
#  'South Carolina' 'North Carolina' 'Ohio' 'Kentucky' 'Mississippi'
#  'Arkansas' 'Oklahoma' 'Kansas' 'South Dakota' 'North Dakota' 'Iowa'
#  'Wisconsin' 'Indiana' 'West Virginia' 'Maryland' 'Delaware' 'New Jersey'
# ...

# %%
df1 = df

# %%
# Feature Engineering
df1['Sales per Unit'] = df1['Total Sales'] / df1['Units Sold']
df1['Profit per Unit'] = df1['Operating Profit'] / df1['Units Sold']
df1['Delivery Efficiency'] = df1['Total Sales'] / df1['Days to Deliver']
df1['Invoice Date'] = pd.to_datetime(df1['Invoice Date'])
df1['Year'] = df1['Invoice Date'].dt.year
df1['Month'] = df1['Invoice Date'].dt.month
df1['Profit Margin'] = (df1['Operating Profit'] / df1['Total Sales']) * 100

df1
# Out:
#      Retailer  Retailer ID Invoice Date     Region          State        City  \
# 0     Walmart      1185732   2022-01-14  Northeast       New York    New York
# 1     Walmart      1185732   2022-01-14  Northeast       New York    New York
# 2     Walmart      1185732   2022-01-14  Northeast       New York    New York
# 3     Walmart      1185732   2022-01-14  Northeast       New York    New York
# 4     Walmart      1185732   2022-01-14  Northeast       New York    New York
# ...       ...          ...          ...        ...            ...         ...
# 3739  Walmart      1185732   2022-12-20  Northeast  New Hampshire  Manchester
# 3740  Walmart      1185732   2022-12-20  Northeast  New Hampshire  Manchester
# 3741  Walmart      1185732   2022-12-20  Northeast  New Hampshire  Manchester
# 3742  Walmart      1185732   2022-12-20  Northeast  New Hampshire  Manchester
# 3743  Walmart      1185732   2022-12-20  Northeast  New Hampshire  Manchester
#
# ...

# %%
# 1. Sales Performance Analysis
# Total Sales by Retailer: Identify which retailers are generating the most revenue. This can help prioritize key accounts.
# Total Sales by Region/State/City: Analyze sales performance across different geographical areas to identify strong and weak markets.
# Top-Selling Beverage Brands: Determine which beverage brands are the most popular and contribute the most to total sales.

import seaborn as sns

# Group the data by retailer and month, and calculate total sales
total_sales_by_retailer_month = df.groupby(['Retailer', 'Month'])['Total Sales'].sum().reset_index()

# Create the side-by-side bar chart with Seaborn
plt.figure(figsize=(12, 8))
sns.barplot(data=total_sales_by_retailer_month, x='Retailer', y='Total Sales', hue='Month', palette='tab10')
plt.title('Total Sales by Retailer and Month')
plt.xlabel('Retailer')
plt.ylabel('Total Sales')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Month', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()


# Total Sales by Region/State/City
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='Region', y='Total Sales', ci=None, palette='tab10')  # Bar chart for total sales by region
plt.title('Total Sales by Region')
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.show()

# Top-Selling Beverage Brands
top_beverage_brands = df.groupby('Beverage Brand')['Total Sales'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x=top_beverage_brands.values, y=top_beverage_brands.index, palette='viridis')  # Horizontal bar chart for top-selling beverage brands
plt.title('Top-Selling Beverage Brands')
plt.xlabel('Total Sales')
plt.ylabel('Beverage Brand')
plt.show()
# Out:
# C:\Users\saivi\AppData\Local\Temp\ipykernel_16956\2967826529.py:25: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='Region', y='Total Sales', ci=None, palette='tab10')  # Bar chart for total sales by region
# C:\Users\saivi\AppData\Local\Temp\ipykernel_16956\2967826529.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Region', y='Total Sales', ci=None, palette='tab10')  # Bar chart for total sales by region
# C:\Users\saivi\AppData\Local\Temp\ipykernel_16956\2967826529.py:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
# 2. Operational Efficiency Analysis
# Days to Deliver Analysis: Evaluate the average delivery times to understand the efficiency of the supply chain. Identify if certain regions or 
# delivery companies have longer delivery times.
# Delivery Company Performance: Compare the performance of different delivery companies in terms of delivery times and reliability.


# Days to Deliver Analysis - Violin Plot of Average Days to Deliver by Region
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Region', y='Days to Deliver')
plt.title('Average Days to Deliver by Region')
plt.xlabel('Region')
plt.ylabel('Average Days to Deliver')
plt.xticks(rotation=45)
plt.show()

# Line Plot of Average Days to Deliver Over Time
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='Invoice Date', y='Days to Deliver')
plt.title('Average Days to Deliver Over Time')
plt.xlabel('Invoice Date')
plt.ylabel('Average Days to Deliver')
plt.xticks(rotation=45)
plt.show()

# 2. Delivery Company Performance
# Bar Plot of Average Delivery Time by Delivery Company
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Delivery Company', y='Days to Deliver', ci=None)
plt.title('Average Delivery Time by Delivery Company')
plt.xlabel('Delivery Company')
plt.ylabel('Average Days to Deliver')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\saivi\AppData\Local\Temp\ipykernel_16956\2447879535.py:28: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='Delivery Company', y='Days to Deliver', ci=None)

# %%
# Operating Profit by Retailer/Region/Brand:

# Bar Plot of Operating Profit by Retailer: Visualize the operating profit generated by each retailer to identify the most profitable retailers.
# Bar Plot of Operating Profit by Region: Analyze the operating profit generated in each region to identify the most profitable regions.
# Bar Plot of Operating Profit by Beverage Brand: Assess the operating profit generated by each beverage brand to identify the most profitable brands.

total_sales_by_retailer = df.groupby(['Retailer'])['Total Sales'].sum().reset_index()

# Create the side-by-side bar chart with Seaborn
plt.figure(figsize=(8, 4))
sns.barplot(data=total_sales_by_retailer, x='Retailer', y='Total Sales', palette='tab10')
plt.title('Total Sales by Retailer')
plt.xlabel('Retailer')
plt.ylabel('Total Sales')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Month', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# Operating Profit by Retailer
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Retailer', y='Operating Profit', ci=None)
plt.title('Operating Profit by Retailer')
plt.xlabel('Retailer')
plt.ylabel('Operating Profit')
plt.xticks(rotation=45)
plt.show()

# Operating Profit by Region
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Region', y='Operating Profit', ci=None)
plt.title('Operating Profit by Region')
plt.xlabel('Region')
plt.ylabel('Operating Profit')
plt.xticks(rotation=45)
plt.show()

# Operating Profit by Beverage Brand
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Beverage Brand', y='Operating Profit', ci=None)
plt.title('Operating Profit by Beverage Brand')
plt.xlabel('Beverage Brand')
plt.ylabel('Operating Profit')
plt.xticks(rotation=45)
plt.show()

# Operating Margin Over Time
plt.figure(figsize=(10, 6))
sns.pointplot(data=df, x='Month', y='Operating Margin', ci=None)
plt.title('Operating Margin Over Time')
plt.xlabel('Month')
plt.ylabel('Operating Margin')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\saivi\AppData\Local\Temp\ipykernel_16956\1747377302.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=total_sales_by_retailer, x='Retailer', y='Total Sales', palette='tab10')
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\saivi\AppData\Local\Temp\ipykernel_16956\1747377302.py:22: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='Retailer', y='Operating Profit', ci=None)
# C:\Users\saivi\AppData\Local\Temp\ipykernel_16956\1747377302.py:31: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='Region', y='Operating Profit', ci=None)
# ...

# %%
df1
# Out:
#      Retailer  Retailer ID Invoice Date     Region          State        City  \
# 0     Walmart      1185732   2022-01-14  Northeast       New York    New York
# 1     Walmart      1185732   2022-01-14  Northeast       New York    New York
# 2     Walmart      1185732   2022-01-14  Northeast       New York    New York
# 3     Walmart      1185732   2022-01-14  Northeast       New York    New York
# 4     Walmart      1185732   2022-01-14  Northeast       New York    New York
# ...       ...          ...          ...        ...            ...         ...
# 3739  Walmart      1185732   2022-12-20  Northeast  New Hampshire  Manchester
# 3740  Walmart      1185732   2022-12-20  Northeast  New Hampshire  Manchester
# 3741  Walmart      1185732   2022-12-20  Northeast  New Hampshire  Manchester
# 3742  Walmart      1185732   2022-12-20  Northeast  New Hampshire  Manchester
# 3743  Walmart      1185732   2022-12-20  Northeast  New Hampshire  Manchester
#
# ...

# %%
# Sales Over Time: Analyze sales data over time (using the Invoice Date) to identify trends, seasonal patterns, and peak sales periods.

df1['Invoice Date'] = pd.to_datetime(df1['Invoice Date'])

# Group the data by 'Invoice Date' and calculate total sales
total_sales_over_time = df1.groupby('Invoice Date')['Total Sales'].sum().reset_index()

# Plot the total sales over time
plt.figure(figsize=(18, 8))
sns.lineplot(data=total_sales_over_time, x='Invoice Date', y='Total Sales', marker='o', color='green')
plt.title('Total Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


# we cant clearly see the trend here, except there been a increase in sales from last day of the month to first day of the next month i.e. 31 January 
# to 1st Feb. To see the trend we can use 3 methods:

# Rolling Average Plot: This smooths out short-term fluctuations and highlights longer-term trends.
# Seasonal Decomposition Plot: This breaks down the time series into trend, seasonal, and residual components.
# Monthly/Quarterly Aggregated Plot: Aggregating the data by month or quarter can make seasonal patterns more apparent.

# %%
# %pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Rolling average plot
# Add a column for rolling average of total sales (e.g., 30-day rolling average)
total_sales_over_time['Rolling Average'] = total_sales_over_time['Total Sales'].rolling(window=30).mean()

# Plot the total sales and rolling average over time
plt.figure(figsize=(18, 8))
sns.lineplot(data=total_sales_over_time, x='Invoice Date', y='Total Sales', marker='o', color='blue', label='Daily Sales')
sns.lineplot(data=total_sales_over_time, x='Invoice Date', y='Rolling Average', marker='', color='red', label='30-Day Rolling Average')
plt.title('Total Sales Over Time with Rolling Average')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()


# 2.Seasonal Decomposition Plot
# Seasonal decomposition using moving averages can break down the time series into its trend, seasonal, and residual components. 

from statsmodels.tsa.seasonal import seasonal_decompose

# Decompose the time series
decomposition = seasonal_decompose(total_sales_over_time.set_index('Invoice Date')['Total Sales'], model='additive', period=30)

# Plot the decomposition
plt.figure(figsize=(14, 10))
decomposition.plot()
plt.tight_layout()
plt.show()


# Sales by Month-Quaterly
# Create a column for year-month
total_sales_over_time['YearMonth'] = total_sales_over_time['Invoice Date'].dt.to_period('M')

# Group the data by year-month and calculate total sales
monthly_sales = total_sales_over_time.groupby('YearMonth')['Total Sales'].sum().reset_index()
monthly_sales['YearMonth'] = monthly_sales['YearMonth'].dt.to_timestamp()

# Plot the monthly aggregated sales
plt.figure(figsize=(18, 8))
sns.lineplot(data=monthly_sales, x='YearMonth', y='Total Sales', marker='o', color='green')
plt.title('Total Sales by Month')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Quaterly Sales Plot
df1['Invoice Date'] = pd.to_datetime(df1['Invoice Date'])

# Add a column for the quarter
df1['Quarter'] = df1['Invoice Date'].dt.to_period('Q')

# Group the data by year-quarter and calculate total sales
quarterly_sales = df1.groupby('Quarter')['Total Sales'].sum().reset_index()
quarterly_sales['Quarter'] = quarterly_sales['Quarter'].dt.to_timestamp()

# Plot the quarterly aggregated sales
plt.figure(figsize=(18, 8))
sns.lineplot(data=quarterly_sales, x='Quarter', y='Total Sales', marker='o', color='purple')
plt.title('Total Sales by Quarter')
plt.xlabel('Quarter')
plt.ylabel('Total Sales')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 6. Customer Behavior and Preferences
# Retailer Purchase Patterns: Study the purchase patterns of different retailers to understand their preferences and buying behavior.

# To analyze customer behavior and preferences through retailer purchase patterns, we can focus on several aspects:
# Potential Analyses:

# 1. Purchase Frequency by Retailer: Determine how often each retailer makes purchases.
# Group by Retailer and count the number of purchases
purchase_frequency = df['Retailer'].value_counts()

# Plotting the purchase frequency by retailer
plt.figure(figsize=(18, 8))
sns.barplot(x=purchase_frequency.index, y=purchase_frequency.values, hue = purchase_frequency.index, legend = 0, palette='viridis')
plt.title('Purchase Frequency by Retailer')
plt.xlabel('Retailer')
plt.ylabel('Number of Purchases')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


# 2. Popular Products by Retailer: Identify which products are most commonly purchased by each retailer.
# Group by Retailer and Beverage Brand, then count the number of purchases
popular_products = df.groupby(['Retailer', 'Beverage Brand']).size().unstack(fill_value=0)

# Plotting the heatmap
plt.figure(figsize=(18, 8))
sns.heatmap(popular_products, cmap='viridis', annot=True, fmt='d')
plt.title('Popular Products by Retailer')
plt.xlabel('Beverage Brand')
plt.ylabel('Retailer')
plt.tight_layout()
plt.show()

# 3. Average Order Value by Retailer: Calculate the average order value for each retailer to understand their spending behavior.
# Calculate average order value by Retailer
average_order_value = df.groupby('Retailer')['Total Sales'].mean()

# Plotting the average order value by retailer
plt.figure(figsize=(18, 8))
sns.barplot(x=average_order_value.index, y=average_order_value.values, hue = average_order_value.index, palette='magma', legend = 0)
plt.title('Average Order Value by Retailer')
plt.xlabel('Retailer')
plt.ylabel('Average Order Value')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 7. Delivery and Logistics Insights
# Correlation Between Days to Deliver and Sales: Investigate if longer delivery times impact the number of units sold or total sales.

# To investigate the correlation between days to deliver and sales, we can perform below steps:
# 1. Correlation Analysis: Calculate the correlation coefficient between "Days to Deliver" and "Total Sales" or "Units Sold".
# 2. Scatter Plot: Visualize the relationship between "Days to Deliver" and "Total Sales" or "Units Sold" using scatter plots.
# 3. Regression Analysis: Fit a regression line to understand the nature and strength of the relationship.

# Calculate the correlation coefficient
correlation_sales = df1['Days to Deliver'].corr(df1['Total Sales'])
correlation_units = df1['Days to Deliver'].corr(df1['Units Sold'])

print(f"Correlation between Days to Deliver and Total Sales: {correlation_sales}")
print(f"Correlation between Days to Deliver and Units Sold: {correlation_units}")


# Scatter plot with regression line for Days to Deliver vs Total Sales
plt.figure(figsize=(18, 8))
sns.regplot(data=df1, x='Days to Deliver', y='Total Sales', line_kws={"color":"r","alpha":0.7,"lw":2})
plt.title('Days to Deliver vs Total Sales with Regression Line')
plt.xlabel('Days to Deliver')
plt.ylabel('Total Sales')
plt.show()

# Scatter plot with regression line for Days to Deliver vs Units Sold
plt.figure(figsize=(18, 8))
sns.regplot(data=df1, x='Days to Deliver', y='Units Sold', line_kws={"color":"r","alpha":0.7,"lw":2})
plt.title('Days to Deliver vs Units Sold with Regression Line')
plt.xlabel('Days to Deliver')
plt.ylabel('Units Sold')
plt.show()
# Out:
# Correlation between Days to Deliver and Total Sales: -0.009704298661258527
# Correlation between Days to Deliver and Units Sold: 0.0004995197507788336

# %%
df1.head()
# Out:
#   Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Walmart      1185732   2022-01-14  Northeast  New York  New York
# 1  Walmart      1185732   2022-01-14  Northeast  New York  New York
# 2  Walmart      1185732   2022-01-14  Northeast  New York  New York
# 3  Walmart      1185732   2022-01-14  Northeast  New York  New York
# 4  Walmart      1185732   2022-01-14  Northeast  New York  New York
#
#   Beverage Brand  Days to Deliver Delivery Company  Price per Unit  ...  \
# 0      Coca-Cola               25             USPS            0.50  ...
# 1      Diet Coke               34            FedEx            0.50  ...
# 2         Sprite               48              UPS            0.40  ...
# 3          Fanta               20             USPS            0.45  ...
# 4       Powerade               26             USPS            0.60  ...
#
#    Total Sales  Operating Profit  Operating Margin  Sales per Unit  \
# ...

# %%
df2=df1

# %%
df2.dtypes
# Out:
# Retailer                       object
# Retailer ID                     int64
# Invoice Date           datetime64[ns]
# Region                         object
# State                          object
# City                           object
# Beverage Brand                 object
# Days to Deliver                 int64
# Delivery Company               object
# Price per Unit                float64
# Units Sold                      int32
# Total Sales                   float64
# Operating Profit              float64
# Operating Margin              float64
# Sales per Unit                float64
# Profit per Unit               float64
# Delivery Efficiency           float64
# Year                            int32
# Month                           int32
# Profit Margin                 float64
# Quarter                 period[Q-DEC]
# dtype: object

# %%
for i in df2.columns:
    if df2[i].dtype == 'object':
        print(i, df2[i].unique())
# Out:
# Retailer ['Walmart' 'Costco' 'CVS' 'Target']
# Region ['Northeast' 'South' 'West' 'Midwest' 'Southeast']
# State ['New York' 'Texas' 'California' 'Illinois' 'Pennsylvania' 'Nevada'
#  'Colorado' 'Washington' 'Florida' 'Minnesota' 'Montana' 'Tennessee'
#  'Nebraska' 'Alabama' 'Maine' 'Wyoming' 'Virginia' 'Michigan' 'Missouri'
#  'Utah' 'Oregon' 'Louisiana' 'Idaho' 'Arizona' 'New Mexico' 'Georgia'
#  'South Carolina' 'North Carolina' 'Ohio' 'Kentucky' 'Mississippi'
#  'Arkansas' 'Oklahoma' 'Kansas' 'South Dakota' 'North Dakota' 'Iowa'
#  'Wisconsin' 'Indiana' 'West Virginia' 'Maryland' 'Delaware' 'New Jersey'
#  'Connecticut' 'Rhode Island' 'Massachusetts' 'Vermont' 'New Hampshire']
# City ['New York' 'Houston' 'San Francisco' 'Los Angeles' 'Chicago' 'Dallas'
#  'Philadelphia' 'Las Vegas' 'Denver' 'Seattle' 'Miami' 'Minneapolis'
#  'Billings' 'Knoxville' 'Omaha' 'Birmingham' 'Portland' 'Orlando' 'Albany'
#  'Cheyenne' 'Richmond' 'Detroit' 'St. Louis' 'Salt Lake City'
# ...

# %%
df2['Retailer'].replace(['Walmart', 'Costco', 'CVS', 'Target'], [0, 1, 2, 3], inplace = True)
# Out:
# C:\Users\saivi\AppData\Local\Temp\ipykernel_16956\1321314813.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['Retailer'].replace(['Walmart', 'Costco', 'CVS', 'Target'], [0, 1, 2, 3], inplace = True)
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply Label Encoding to each categorical column
for col in ['Region', 'State', 'City', 'Beverage Brand', 'Delivery Company']:
    df2[col] = label_encoder.fit_transform(df2[col])

# %%
# Assuming df is your DataFrame containing the 'Quarter' column
df2['Quarter'] = df2['Quarter'].dt.to_timestamp().dt.to_period('Q').astype(str).str[-1:].astype(int)

# %%
# Correlation
df2.head()
# Out:
#    Retailer  Retailer ID Invoice Date  Region  State  City  Beverage Brand  \
# 0         0      1185732   2022-01-14       1     29    33               0
# 1         0      1185732   2022-01-14       1     29    33               2
# 2         0      1185732   2022-01-14       1     29    33               5
# 3         0      1185732   2022-01-14       1     29    33               3
# 4         0      1185732   2022-01-14       1     29    33               4
#
#    Days to Deliver  Delivery Company  Price per Unit  ...  Total Sales  \
# 0               25                 3            0.50  ...       6000.0
# 1               34                 1            0.50  ...       5000.0
# 2               48                 2            0.40  ...       4000.0
# 3               20                 3            0.45  ...       3825.0
# 4               26                 3            0.60  ...       5400.0
#
#    Operating Profit  Operating Margin  Sales per Unit  Profit per Unit  \
# ...

# %%
df2.dtypes
# Out:
# Retailer                        int64
# Retailer ID                     int64
# Invoice Date           datetime64[ns]
# Region                          int32
# State                           int32
# City                            int32
# Beverage Brand                  int32
# Days to Deliver                 int64
# Delivery Company                int32
# Price per Unit                float64
# Units Sold                      int32
# Total Sales                   float64
# Operating Profit              float64
# Operating Margin              float64
# Sales per Unit                float64
# Profit per Unit               float64
# Delivery Efficiency           float64
# Year                            int32
# Month                           int32
# Profit Margin                 float64
# Quarter                         int32
# dtype: object

# %%
import seaborn as sns

corr_matrix = df2.corr()
plt.figure(figsize=(20, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
df3 = df2

# %%
df3 = df3.drop(['Invoice Date'], axis=1)

# %%
df3
# Out:
#       Retailer  Retailer ID  Region  State  City  Beverage Brand  \
# 0            0      1185732       1     29    33               0
# 1            0      1185732       1     29    33               2
# 2            0      1185732       1     29    33               5
# 3            0      1185732       1     29    33               3
# 4            0      1185732       1     29    33               4
# ...        ...          ...     ...    ...   ...             ...
# 3739         0      1185732       1     26    28               2
# 3740         0      1185732       1     26    28               5
# 3741         0      1185732       1     26    28               3
# 3742         0      1185732       1     26    28               4
# 3743         0      1185732       1     26    28               1
#
#       Days to Deliver  Delivery Company  Price per Unit  Units Sold  \
# 0                  25                 3            0.50       12000
# ...

# %%
import pandas as pd

df3['Sales per Unit'].fillna(df3['Sales per Unit'].mean(), inplace=True)
df3['Profit per Unit'].fillna(df3['Profit per Unit'].mean(), inplace=True)
df3['Profit Margin'].fillna(df3['Profit Margin'].mean(), inplace=True)
# Out:
# C:\Users\saivi\AppData\Local\Temp\ipykernel_16956\3305416695.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3['Sales per Unit'].fillna(df3['Sales per Unit'].mean(), inplace=True)
# C:\Users\saivi\AppData\Local\Temp\ipykernel_16956\3305416695.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df3.isnull().sum()
# Out:
# Retailer               0
# Retailer ID            0
# Region                 0
# State                  0
# City                   0
# Beverage Brand         0
# Days to Deliver        0
# Delivery Company       0
# Price per Unit         0
# Units Sold             0
# Total Sales            0
# Operating Profit       0
# Operating Margin       0
# Sales per Unit         0
# Profit per Unit        0
# Delivery Efficiency    0
# Year                   0
# Month                  0
# Profit Margin          0
# Quarter                0
# dtype: int64

# %%
from sklearn.ensemble import RandomForestRegressor


X = df3.drop(columns=['Total Sales'], axis = 1)  # Assuming 'Total Sales' is the target
y = df3['Total Sales']

model = RandomForestRegressor()
model.fit(X, y)

# Feature importance
importances = model.feature_importances_
feature_importance = pd.DataFrame({'Feature': X.columns, 'Importance': importances})
print(feature_importance.sort_values(by='Importance', ascending=False))
# Out:
#                 Feature  Importance
# 10     Operating Profit    0.881857
# 17        Profit Margin    0.096993
# 11     Operating Margin    0.012032
# 9            Units Sold    0.002615
# 5        Beverage Brand    0.001181
# 12       Sales per Unit    0.000971
# 8        Price per Unit    0.000903
# 4                  City    0.000599
# 13      Profit per Unit    0.000558
# 14  Delivery Efficiency    0.000513
# 1           Retailer ID    0.000461
# 16                Month    0.000297
# 6       Days to Deliver    0.000265
# 3                 State    0.000240
# 18              Quarter    0.000182
# 7      Delivery Company    0.000166
# 0              Retailer    0.000104
# 2                Region    0.000065
# 15                 Year    0.000000

# %%
X.isnull().sum()
# Out:
# Retailer               0
# Retailer ID            0
# Region                 0
# State                  0
# City                   0
# Beverage Brand         0
# Days to Deliver        0
# Delivery Company       0
# Price per Unit         0
# Units Sold             0
# Operating Profit       0
# Operating Margin       0
# Sales per Unit         0
# Profit per Unit        0
# Delivery Efficiency    0
# Year                   0
# Month                  0
# Profit Margin          0
# Quarter                0
# dtype: int64

# %%
X['Sales per Unit'].fillna(method='ffill', inplace=True)
X['Profit per Unit'].fillna(method='ffill', inplace=True)
X['Profit Margin'].fillna(method='ffill', inplace=True)
# Out:
# C:\Users\saivi\AppData\Local\Temp\ipykernel_16956\3024798055.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['Sales per Unit'].fillna(method='ffill', inplace=True)
# C:\Users\saivi\AppData\Local\Temp\ipykernel_16956\3024798055.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   X['Sales per Unit'].fillna(method='ffill', inplace=True)
# ...

# %%
# Feature Importance scores
from sklearn.feature_selection import mutual_info_classif

importance = mutual_info_classif(X, y)
feature_imp = pd.Series(importances, df3.columns[0:len(df3.columns)-1])
feature_imp.plot(kind = 'barh', color ='teal')
plt.show()

# %%
from sklearn.linear_model import LassoCV

model = LassoCV()
model.fit(X, y)

# Selected features
coef = pd.Series(model.coef_, index=X.columns)
print(coef[coef > 0])
# Out:
# Units Sold          0.274852
# Operating Profit    1.266969
# dtype: float64

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

model = LinearRegression()
rfe = RFE(model, n_features_to_select=10)
fit = rfe.fit(X, y)

# Selected features
selected_features = X.columns[rfe.support_]
print(selected_features)
# Out:
# Index(['Retailer', 'Region', 'Days to Deliver', 'Price per Unit',
#        'Operating Margin', 'Sales per Unit', 'Profit per Unit', 'Month',
#        'Profit Margin', 'Quarter'],
#       dtype='object')

# %%
X1 = df3.drop('Total Sales', axis = 1)
y1 = df3['Total Sales']

# Normalization
from sklearn.preprocessing import MinMaxScaler

Scaler = MinMaxScaler()
norm_data = Scaler.fit_transform(X1)
norm_X = pd.DataFrame(norm_data, columns = X1.columns)
norm_X
# Out:
#       Retailer  Retailer ID  Region     State      City  Beverage Brand  \
# 0          0.0     0.825994    0.25  0.617021  0.673469             0.0
# 1          0.0     0.825994    0.25  0.617021  0.673469             0.4
# 2          0.0     0.825994    0.25  0.617021  0.673469             1.0
# 3          0.0     0.825994    0.25  0.617021  0.673469             0.6
# 4          0.0     0.825994    0.25  0.617021  0.673469             0.8
# ...        ...          ...     ...       ...       ...             ...
# 3739       0.0     0.825994    0.25  0.553191  0.571429             0.4
# 3740       0.0     0.825994    0.25  0.553191  0.571429             1.0
# 3741       0.0     0.825994    0.25  0.553191  0.571429             0.6
# 3742       0.0     0.825994    0.25  0.553191  0.571429             0.8
# 3743       0.0     0.825994    0.25  0.553191  0.571429             0.2
#
#       Days to Deliver  Delivery Company  Price per Unit  Units Sold  \
# ...

# %%
print(df3.shape)
print(X1.shape)
print(y1.shape)
# Out:
# (3744, 20)
# (3744, 19)
# (3744,)

# %%
y1
# Out:
# 0       6000.0
# 1       5000.0
# 2       4000.0
# 3       3825.0
# 4       5400.0
#          ...
# 3739    2600.0
# 3740    2438.0
# 3741    2113.0
# 3742    2438.0
# 3743    3400.0
# Name: Total Sales, Length: 3744, dtype: float64

# %%
# Model Training

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(norm_X, y1, test_size=0.3)

lm = LinearRegression()
model = lm.fit(X_train, y_train)

print(model.coef_, model.intercept_)
print(model.score(X_test,y_test))
# Out:
# [ 4.22474910e+01 -1.59353937e+02 -1.44093621e+02 -6.33584876e+01
#   4.38580491e+01  7.49248717e+01  1.77285665e+02  7.04631268e-01
#   4.05329800e+03  2.61972867e+03  5.78609209e+03  8.44903489e+03
#   9.82736501e+02 -3.90719907e+03  9.05597488e+02 -4.49063009e-11
#   1.11466780e+02 -7.97230785e+03 -8.23230280e+01] -822.9497686831787
# 0.9821659168339845

# %%
# Model Prediction

predictions = lm.predict(X_test)

# Create a DataFrame for comparison
comparison_df = pd.DataFrame({
    "Actual Total Sales": y_test,
    "Predicted Total Sales": predictions
})
comparison_df["Residuals"] = comparison_df["Actual Total Sales"] - comparison_df["Predicted Total Sales"]

# Plotting the actual vs predicted values
plt.figure(figsize=(18, 8))
plt.scatter(y_test, predictions, color='blue', label='Predicted')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linewidth=2, label='Ideal Fit')
plt.xlabel('Actual Total Sales')
plt.ylabel('Predicted Total Sales')
plt.title('Actual vs Predicted Total Sales')
plt.legend()
plt.show()

# Optional: Outputting the DataFrame if needed
# periscope.output(comparison_df)
print(comparison_df)
# Out:
#       Actual Total Sales  Predicted Total Sales   Residuals
# 1190              1013.0             949.062048   63.937952
# 2900               150.0            -170.634695  320.634695
# 245               4063.0            3697.063281  365.936719
# 2115              3038.0            2965.244640   72.755360
# 1628              1350.0            1473.980430 -123.980430
# ...                  ...                    ...         ...
# 3070              1250.0            1234.438995   15.561005
# 1337              3850.0            3544.340699  305.659301
# 588               2200.0            2322.054764 -122.054764
# 1670              1925.0            2047.742340 -122.742340
# 1840              2888.0            2850.588681   37.411319
#
# [1124 rows x 3 columns]

# %%
y_train.shape
# Out:
# (2620,)

# %%
# Select one feature from X_test for plotting
feature_index = 8 # change this index to select a different feature
X_test_feature = X_test.iloc[:, feature_index]

# Plotting the actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(X_test_feature, y_test, color='blue', label='Actual')
plt.scatter(X_test_feature, predictions, color='red', label='Predicted', alpha=0.5)

# Fit the regression line on the predicted values
coeff = np.polyfit(X_test_feature, predictions, 1)
poly_eq = np.poly1d(coeff)
plt.plot(X_test_feature, poly_eq(X_test_feature), color='black', label='Regression Line')

plt.xlabel(f'Feature {feature_index}')
plt.ylabel('Total Sales')
plt.title('Actual vs Predicted Total Sales with Regression Line')
plt.legend()
plt.show()

# %%
from sklearn.metrics import r2_score, mean_squared_error

# Calculate R²
r2 = r2_score(y_test, predictions)
print(f'R²: {r2}')

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f'RMSE: {rmse}')
# Out:
# R²: 0.9821659168339845
# RMSE: 193.59952895573008

# %%
# TIME SERIES FORECASTING
df4 = df2[['Invoice Date', 'Total Sales']]
df4
# Out:
#      Invoice Date  Total Sales
# 0      2022-01-14       6000.0
# 1      2022-01-14       5000.0
# 2      2022-01-14       4000.0
# 3      2022-01-14       3825.0
# 4      2022-01-14       5400.0
# ...           ...          ...
# 3739   2022-12-20       2600.0
# 3740   2022-12-20       2438.0
# 3741   2022-12-20       2113.0
# 3742   2022-12-20       2438.0
# 3743   2022-12-20       3400.0
#
# [3744 rows x 2 columns]

# %%
df4.dtypes
# Out:
# Invoice Date    datetime64[ns]
# Total Sales            float64
# dtype: object

# %%
# Convert 'Invoice Date' to datetime format if it is not already
df4['Invoice Date'] = pd.to_datetime(df4['Invoice Date'])

# Set 'Invoice Date' as the index
df4.set_index('Invoice Date', inplace=True)

# Ensure the data is sorted by date
df4.sort_index(inplace=True)

# Plot the time series data
plt.figure(figsize=(10, 6))
plt.plot(df4.index, df4['Total Sales'], label='Total Sales')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.title('Total Sales Over Time')
plt.legend()
plt.show()
# Out:
# C:\Users\saivi\AppData\Local\Temp\ipykernel_16956\2634029833.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['Invoice Date'] = pd.to_datetime(df4['Invoice Date'])
# C:\Users\saivi\AppData\Local\Temp\ipykernel_16956\2634029833.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4.sort_index(inplace=True)

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import numpy as np

# Selecting the target variable for time series forecasting
data = df4['Total Sales']

# Split the data into training and testing sets
train_size = int(len(data) * 0.8)
train, test = data[:train_size], data[train_size:]

# Build and train the ARIMA model
model = ARIMA(train, order=(5, 1, 0))  # Adjust the order (p,d,q) as needed
model_fit = model.fit()

# Make predictions
predictions = model_fit.forecast(steps=len(test))

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(test, predictions))
print(f'RMSE: {rmse}')

# Plot the predictions against the actual values
plt.figure(figsize=(10, 6))
plt.plot(train, label='Train')
plt.plot(test, label='Test')
plt.plot(test.index, predictions, color='red', label='Predictions')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.title('ARIMA Model - Total Sales Forecast')
plt.legend()
plt.show()
# Out:
# C:\Users\saivi\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\saivi\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\saivi\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %%
from statsmodels.tsa.stattools import adfuller
test_result=adfuller(df4['Total Sales'])
print(test_result)
# Out:
# (-5.7504559368246415, 5.983366110547507e-07, 30, 3713, {'1%': -3.4321124095433113, '5%': -2.86231873504501, '10%': -2.5671845317886093}, 63355.48867572978)

# %%
def adfuller_test(sales):
    result=adfuller(sales)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )

    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary")
    else:
        print("weak evidence against null hypothesis,indicating it is non-stationary ")

adfuller_test(df4['Total Sales'])
# Out:
# ADF Test Statistic : -5.7504559368246415
# p-value : 5.983366110547507e-07
# #Lags Used : 30
# Number of Observations : 3713
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary

# %%
# Create Auto-correlation
# I am going to create auto-correlation :

from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df4['Total Sales'])
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
import statsmodels.api as sm
fig = plt.figure(figsize=(18,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df4['Total Sales'].dropna(),lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df4['Total Sales'].dropna(),lags=40,ax=ax2)

# Autocorrelation and Partial Autocorrelation Plot suggests that:
# Significant spikes or oscillations at certain lags, it suggests that there might be some underlying pattern 
# or seasonality in the data.

# %%
df4['Differenced Sales'] = df4['Total Sales'].diff()
adfuller_test(df4['Differenced Sales'].dropna())
df4['Differenced Sales'].plot()
# Out:
# C:\Users\saivi\AppData\Local\Temp\ipykernel_16956\1394924382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['Differenced Sales'] = df4['Total Sales'].diff()
# ADF Test Statistic : -19.063454348125916
# p-value : 0.0
# #Lags Used : 30
# Number of Observations : 3712
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary
# <Axes: xlabel='Invoice Date'>

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df4['Differenced Sales'].dropna(),lags=40,ax=ax1)

# %%
from statsmodels.tsa.arima.model import ARIMA

# Fit the ARIMA model
model = ARIMA(df4['Differenced Sales'], order=(5, 1, 3))
model_fit = model.fit()

# Print the model summary
print(model_fit.summary())
# Out:
# C:\Users\saivi\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\saivi\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\saivi\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ...
# Dep. Variable:      Differenced Sales   No. Observations:                 3744
# ...

# %%
# Check for duplicate indices
print(df4.index.duplicated().sum())
# Out:
# 3474

# %%
# Reset index if there are duplicates
if df4.index.duplicated().sum() > 0:
    df4 = df4.reset_index(drop=True)

# %%
df4.shape
# Out:
# (3744, 2)

# %%
# Make predictions
start = 3000  # start from the end of the current data
end = 3744  # extend 100 steps beyond the current length

df4['forecast'] = model_fit.predict(start=start, end=end, dynamic=True)

# Plot the results
plt.figure(figsize=(12, 8))
plt.plot(df4['Differenced Sales'], label='Total Sales')
plt.plot(df4['forecast'], label='Forecast', linestyle='--')
plt.legend()
plt.title('Total Sales and Forecast')
plt.xlabel('Time')
plt.ylabel('Sales')
plt.grid(True)
plt.show()
# Out:
# C:\Users\saivi\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\saivi\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
import statsmodels.api as sm
model=sm.tsa.statespace.SARIMAX(df4['Differenced Sales'],order=(5, 1, 3),seasonal_order=(1,1,1,12))
results=model.fit()
df4['forecast']=results.predict(start=3000,end=3744,dynamic=True)
df4[['Differenced Sales','forecast']].plot(figsize=(12,8))
# Out:
# C:\Users\saivi\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\saivi\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <Axes: >

# %%
coc_data = pd.read_csv("Coca Cola Sales Data.csv")
coc_data
# Out:
#      Retailer  Retailer ID Invoice Date     Region          State        City  \
# 0     Walmart      1185732    1/14/2022  Northeast       New York    New York
# 1     Walmart      1185732    1/14/2022  Northeast       New York    New York
# 2     Walmart      1185732    1/14/2022  Northeast       New York    New York
# 3     Walmart      1185732    1/14/2022  Northeast       New York    New York
# 4     Walmart      1185732    1/14/2022  Northeast       New York    New York
# ...       ...          ...          ...        ...            ...         ...
# 3739  Walmart      1185732   12/20/2022  Northeast  New Hampshire  Manchester
# 3740  Walmart      1185732   12/20/2022  Northeast  New Hampshire  Manchester
# 3741  Walmart      1185732   12/20/2022  Northeast  New Hampshire  Manchester
# 3742  Walmart      1185732   12/20/2022  Northeast  New Hampshire  Manchester
# 3743  Walmart      1185732   12/20/2022  Northeast  New Hampshire  Manchester
#
# ...

# %%
coc_data['Invoice Date'] = pd.to_datetime(coc_data['Invoice Date'])
df_sorted = coc_data.sort_values(by = ['Retailer', 'Invoice Date'])
df_sorted.head(10)
# Out:
#     Retailer  Retailer ID Invoice Date Region       State     City  \
# 648      CVS      1128299   2022-01-03   West  Washington  Seattle
# 649      CVS      1128299   2022-01-03   West  Washington  Seattle
# 650      CVS      1128299   2022-01-03   West  Washington  Seattle
# 651      CVS      1128299   2022-01-03   West  Washington  Seattle
# 652      CVS      1128299   2022-01-03   West  Washington  Seattle
# 653      CVS      1128299   2022-01-03   West  Washington  Seattle
# 576      CVS      1128299   2022-01-05   West    Colorado   Denver
# 577      CVS      1128299   2022-01-05   West    Colorado   Denver
# 578      CVS      1128299   2022-01-05   West    Colorado   Denver
# 579      CVS      1128299   2022-01-05   West    Colorado   Denver
#
#     Beverage Brand  Days to \nDeliver Delivery \nCompany Price per \nUnit  \
# 648      Coca-Cola                 55              FedEx           $0.40
# 649      Diet Coke                 39                DHL           $0.50
# ...

# %%
df_sorted = df_sorted.rename(columns={
    'Days to \nDeliver': 'Days to Deliver',
    'Delivery \nCompany': 'Delivery Company',
    'Price per \nUnit' : 'Price per Unit'
})

df_sorted.columns
# Out:
# Index(['Retailer', 'Retailer ID', 'Invoice Date', 'Region', 'State', 'City',
#        'Beverage Brand', 'Days to Deliver', 'Delivery Company',
#        'Price per Unit', 'Units Sold', 'Total Sales', 'Operating Profit',
#        'Operating Margin'],
#       dtype='object')

# %%
df_sorted['Retailer'].unique()
# Out:
# array(['CVS', 'Costco', 'Target', 'Walmart'], dtype=object)

# %%
df_sorted['Beverage Brand'].unique()
# Out:
# array(['Coca-Cola', 'Diet Coke', 'Sprite', 'Fanta', 'Powerade',
#        'Dasani Water'], dtype=object)

# %%
df_1 = df_sorted

# %%
pip install pandas yfinance
# Out:
# ...
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#       --------------------------------------- 0.0/3.0 MB 991.0 kB/s eta 0:00:03
#      - -------------------------------------- 0.1/3.0 MB 1.2 MB/s eta 0:00:03
#      --- ------------------------------------ 0.2/3.0 MB 1.8 MB/s eta 0:00:02
#      ----- ---------------------------------- 0.4/3.0 MB 2.3 MB/s eta 0:00:02
#      ------- -------------------------------- 0.6/3.0 MB 2.5 MB/s eta 0:00:01
#      ------------- -------------------------- 1.0/3.0 MB 4.0 MB/s eta 0:00:01
#      ------------------- -------------------- 1.4/3.0 MB 4.7 MB/s eta 0:00:01
#      --------------------------------- ------ 2.5/3.0 MB 6.8 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 7.2 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
# ...

# %%
import yfinance as yf
import pandas as pd

df_coca_cola = df_1[df_1['Beverage Brand'] == 'Coca-Cola']

start_date = df_coca_cola['Invoice Date'].min()
end_date = df_coca_cola['Invoice Date'].max()
stock_data = yf.download('KO', start=start_date, end=end_date)

# Reset index to have 'Date' column
stock_data = stock_data['Adj Close'].reset_index()

# Merge sales data with stock data
merged_data = pd.merge(df_coca_cola, stock_data, left_on='Invoice Date', right_on='Date', how='left')

# Drop the 'Date' column after merge
merged_data = merged_data.drop(columns=['Date'])

# Display the merged DataFrame
print(merged_data)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Retailer  Retailer ID Invoice Date     Region          State         City  \
# 0        CVS      1128299   2022-01-03       West     Washington      Seattle
# 1        CVS      1128299   2022-01-05       West       Colorado       Denver
# 2        CVS      1128299   2022-01-13       West     New Mexico  Albuquerque
# 3        CVS      1128299   2022-01-15       West         Nevada    Las Vegas
# 4        CVS      1128299   2022-01-17       West         Oregon     Portland
# ..       ...          ...          ...        ...            ...          ...
# 619  Walmart      1185732   2022-12-17    Midwest       Michigan      Detroit
# 620  Walmart      1185732   2022-12-17  Northeast        Vermont   Burlington
# 621  Walmart      1185732   2022-12-20  Northeast  West Virginia   Charleston
# 622  Walmart      1185732   2022-12-20  Northeast  New Hampshire   Manchester
# ...

# %%
merged_data.isna().sum()
# Out:
# Retailer              0
# Retailer ID           0
# Invoice Date          0
# Region                0
# State                 0
# City                  0
# Beverage Brand        0
# Days to Deliver       0
# Delivery Company      0
# Price per Unit        0
# Units Sold            0
# Total Sales           0
# Operating Profit      0
# Operating Margin      0
# Adj Close           201
# dtype: int64

# %%
# Interpolate missing values
merged_data['Adj Close'] = merged_data['Adj Close'].interpolate()

# Display the DataFrame to verify
print(merged_data)
# Out:
#     Retailer  Retailer ID Invoice Date     Region          State         City  \
# 0        CVS      1128299   2022-01-03       West     Washington      Seattle
# 1        CVS      1128299   2022-01-05       West       Colorado       Denver
# 2        CVS      1128299   2022-01-13       West     New Mexico  Albuquerque
# 3        CVS      1128299   2022-01-15       West         Nevada    Las Vegas
# 4        CVS      1128299   2022-01-17       West         Oregon     Portland
# ..       ...          ...          ...        ...            ...          ...
# 619  Walmart      1185732   2022-12-17    Midwest       Michigan      Detroit
# 620  Walmart      1185732   2022-12-17  Northeast        Vermont   Burlington
# 621  Walmart      1185732   2022-12-20  Northeast  West Virginia   Charleston
# 622  Walmart      1185732   2022-12-20  Northeast  New Hampshire   Manchester
# 623  Walmart      1185732   2022-12-21    Midwest           Ohio     Columbus
#
# ...

# %%
# Perform correlation analysis
import seaborn as sns

corr_data= merged_data[['Total Sales', 'Price per Unit', 'Units Sold', 'Operating Profit', 'Operating Margin', 'Adj Close']].copy()
corr_data['Total Sales'] = corr_data['Total Sales'].str.replace('[\$,]', '', regex=True).astype(float)
corr_data['Price per Unit'] = corr_data['Price per Unit'].str.replace('[\$,]', '', regex=True).astype(float)
corr_data['Units Sold'] = corr_data['Units Sold'].str.replace(',', '').astype(int)
corr_data['Operating Profit'] = corr_data['Operating Profit'].str.replace('[\$,]', '', regex=True).astype(float)
corr_data['Operating Margin'] = corr_data['Operating Margin'].str.replace('%', '', regex=True).astype(float) / 100


correlation = corr_data.corr()
sns.heatmap(correlation, annot =True)
# Out:
# <Axes: >

# %%
correlation
# Out:
#                   Total Sales  Price per Unit  Units Sold  Operating Profit  \
# Total Sales          1.000000        0.737435    0.784450          0.958435
# Price per Unit       0.737435        1.000000    0.188757          0.643846
# Units Sold           0.784450        0.188757    1.000000          0.808144
# Operating Profit     0.958435        0.643846    0.808144          1.000000
# Operating Margin     0.310609        0.091074    0.395373          0.541219
# Adj Close            0.266480        0.260235    0.162118          0.219084
#
#                   Operating Margin  Adj Close
# Total Sales               0.310609   0.266480
# Price per Unit            0.091074   0.260235
# Units Sold                0.395373   0.162118
# Operating Profit          0.541219   0.219084
# Operating Margin          1.000000  -0.005497
# Adj Close                -0.005497   1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Scatter plot: Total Sales vs Adj Close
sns.scatterplot(data=corr_data, x='Total Sales', y='Adj Close')
plt.title('Total Sales vs Coca-Cola Stock Price')
plt.show()

# %%
# Scatter plot: Price per Unit vs Adj Close
sns.scatterplot(data=corr_data, x='Price per Unit', y='Adj Close')
plt.title('Price per Unit vs Coca-Cola Stock Price')
plt.show()

# Scatter plot: Units Sold vs Adj Close
sns.scatterplot(data=corr_data, x='Units Sold', y='Adj Close')
plt.title('Units Sold vs Coca-Cola Stock Price')
plt.show()

# Scatter plot: Operating Profit vs Adj Close
sns.scatterplot(data=corr_data, x='Operating Profit', y='Adj Close')
plt.title('Operating Profit vs Coca-Cola Stock Price')
plt.show()

# Scatter plot: Operating Margin vs Adj Close
sns.scatterplot(data=corr_data, x='Operating Margin', y='Adj Close')
plt.title('Operating Margin vs Coca-Cola Stock Price')
plt.show()

# %%
df1
# Out:
#       Retailer  Retailer ID Invoice Date  Region  State  City  Beverage Brand  \
# 0            0      1185732   2022-01-14       1     29    33               0
# 1            0      1185732   2022-01-14       1     29    33               2
# 2            0      1185732   2022-01-14       1     29    33               5
# 3            0      1185732   2022-01-14       1     29    33               3
# 4            0      1185732   2022-01-14       1     29    33               4
# ...        ...          ...          ...     ...    ...   ...             ...
# 3739         0      1185732   2022-12-20       1     26    28               2
# 3740         0      1185732   2022-12-20       1     26    28               5
# 3741         0      1185732   2022-12-20       1     26    28               3
# 3742         0      1185732   2022-12-20       1     26    28               4
# 3743         0      1185732   2022-12-20       1     26    28               1
#
# ...

# %%
# Exporting the total data for Analysis in Power BI
df_2 = pd.read_csv("Coca Cola Sales Data.csv")

# Renaming Columns
df_2 = df_2.rename(columns={
    'Days to \nDeliver': 'Days to Deliver',
    'Delivery \nCompany': 'Delivery Company',
    'Price per \nUnit' : 'Price per Unit'
})

# Remove non-numeric characters and convert to numeric
df_2['Price per Unit'] = df_2['Price per Unit'].str.replace('[\$,]', '', regex=True).astype(float)
df_2['Units Sold'] = df_2['Units Sold'].str.replace(',', '').astype(int)
df_2['Total Sales'] = df_2['Total Sales'].str.replace('[\$,]', '', regex=True).astype(float)
df_2['Operating Profit'] = df_2['Operating Profit'].str.replace('[\$,]', '', regex=True).astype(float)
df_2['Operating Margin'] = df_2['Operating Margin'].str.replace('%', '', regex=True).astype(float) / 100

df1 = df_2

# Feature Engineering
df1['Sales per Unit'] = df1['Total Sales'] / df1['Units Sold']
df1['Profit per Unit'] = df1['Operating Profit'] / df1['Units Sold']
df1['Delivery Efficiency'] = df1['Total Sales'] / df1['Days to Deliver']
df1['Invoice Date'] = pd.to_datetime(df1['Invoice Date'])
df1['Year'] = df1['Invoice Date'].dt.year
df1['Month'] = df1['Invoice Date'].dt.month
df1['Profit Margin'] = (df1['Operating Profit'] / df1['Total Sales']) * 100

df1_sorted = df1.sort_values(by = ['Retailer', 'Invoice Date'])

start_date = df1['Invoice Date'].min()
end_date = df1['Invoice Date'].max()
stock_data_1 = yf.download('KO', start=start_date, end=end_date)

# Reset index to have 'Date' column
stock_data_1 = stock_data_1['Adj Close'].reset_index()

# Merge sales data with stock data
merged_data_1 = pd.merge(df1, stock_data_1, left_on='Invoice Date', right_on='Date', how='left')

# Interpolate missing values
merged_data_1['Adj Close'] = merged_data_1['Adj Close'].interpolate()

# Drop the 'Date' column after merge
merged_data_1 = merged_data_1.drop(columns=['Date'])

# Print merged data
merged_data_1
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Retailer  Retailer ID Invoice Date     Region          State        City  \
# 0     Walmart      1185732   2022-01-14  Northeast       New York    New York
# 1     Walmart      1185732   2022-01-14  Northeast       New York    New York
# 2     Walmart      1185732   2022-01-14  Northeast       New York    New York
# 3     Walmart      1185732   2022-01-14  Northeast       New York    New York
# 4     Walmart      1185732   2022-01-14  Northeast       New York    New York
# ...       ...          ...          ...        ...            ...         ...
# 3739  Walmart      1185732   2022-12-20  Northeast  New Hampshire  Manchester
# 3740  Walmart      1185732   2022-12-20  Northeast  New Hampshire  Manchester
# 3741  Walmart      1185732   2022-12-20  Northeast  New Hampshire  Manchester
# 3742  Walmart      1185732   2022-12-20  Northeast  New Hampshire  Manchester
# ...

# %%
merged_data_1['Sales per Unit'] = merged_data_1['Sales per Unit'].interpolate()
merged_data_1['Profit per Unit'] = merged_data_1['Profit per Unit'].interpolate()
merged_data_1['Profit Margin'] = merged_data_1['Profit Margin'].interpolate()

# %%
merged_data_1.isna().sum()
# Out:
# Retailer               0
# Retailer ID            0
# Invoice Date           0
# Region                 0
# State                  0
# City                   0
# Beverage Brand         0
# Days to Deliver        0
# Delivery Company       0
# Price per Unit         0
# Units Sold             0
# Total Sales            0
# Operating Profit       0
# Operating Margin       0
# Sales per Unit         0
# Profit per Unit        0
# Delivery Efficiency    0
# Year                   0
# Month                  0
# Profit Margin          0
# Adj Close              0
# dtype: int64

# %%
merged_data_1 = merged_data_1.sort_values(by = ['Retailer', 'Invoice Date'])

# %%
# Save the merged_data_1 DataFrame to a CSV file
merged_data_1.to_csv(r'C:\Users\saivi\OneDrive\Desktop\Data Science\Projects\Coca Cola Project\merged_data.csv', index=False)

# %%
merged_data_1.columns
# Out:
# Index(['Retailer', 'Retailer ID', 'Invoice Date', 'Region', 'State', 'City',
#        'Beverage Brand', 'Days to Deliver', 'Delivery Company',
#        'Price per Unit', 'Units Sold', 'Total Sales', 'Operating Profit',
#        'Operating Margin', 'Sales per Unit', 'Profit per Unit',
#        'Delivery Efficiency', 'Year', 'Month', 'Profit Margin', 'Adj Close'],
#       dtype='object')
